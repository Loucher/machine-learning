# %% [markdown]
# ## Convolutional Neural Networks
#
# ---
#
# In this notebook, we train a CNN to classify images from the CIFAR-10 database.
#
# ### 1. Load CIFAR-10 Database

# %%
import keras
from keras.datasets import cifar10

# load the pre-shuffled train and test data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### 2. Visualize the First 24 Training Images

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20,5))
for i in range(36):
    ax = fig.add_subplot(3, 12, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_train[i]))

# %% [markdown]
# ### 3. Rescale the Images by Dividing Every Pixel in Every Image by 255

# %%
# rescale [0,255] --> [0,1]
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %% [markdown]
# ### 4.  Break Dataset into Training, Testing, and Validation Sets

# %%
from keras.utils import np_utils

# one-hot encode the labels
num_classes = len(np.unique(y_train))
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# break training set into training and validation sets
(x_train, x_valid) = x_train[5000:], x_train[:5000]
(y_train, y_valid) = y_train[5000:], y_train[:5000]

# print shape of training set
print('x_train shape:', x_train.shape)

# print number of training, validation, and test images
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print(x_valid.shape[0], 'validation samples')
# Out:
# x_train shape: (45000, 32, 32, 3)
# 45000 train samples
# 10000 test samples
# 5000 validation samples

# %% [markdown]
# ### 5. Define the Model Architecture

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu', input_shape=(32, 32, 3)))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=50, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(500, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_7 (Conv2D)            (None, 32, 32, 64)        832
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 16, 16, 50)        12850
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 8, 8, 50)          0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 8, 8, 64)          12864
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 500)               512500
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 10)                5010
# =================================================================
# Total params: 544,056
# Trainable params: 544,056
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 6. Compile the Model

# %%
# compile the model
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', 
                  metrics=['accuracy'])

# %% [markdown]
# ### 7. Train the Model

# %%
from keras.callbacks import ModelCheckpoint   

# train the model
checkpointer = ModelCheckpoint(filepath='model.weights.best.hdf5', verbose=1, 
                               save_best_only=True)
hist = model.fit(x_train, y_train, batch_size=32, epochs=100,
          validation_data=(x_valid, y_valid), callbacks=[checkpointer], 
          verbose=2, shuffle=True)
# Out:
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/100
#  - 6s - loss: 1.5652 - acc: 0.4324 - val_loss: 1.2175 - val_acc: 0.5686
#
# Epoch 00001: val_loss improved from inf to 1.21750, saving model to model.weights.best.hdf5
# Epoch 2/100
#  - 5s - loss: 1.2267 - acc: 0.5652 - val_loss: 1.5277 - val_acc: 0.4918
#
# Epoch 00002: val_loss did not improve from 1.21750
# Epoch 3/100
#  - 5s - loss: 1.0976 - acc: 0.6160 - val_loss: 1.0647 - val_acc: 0.6324
#
# Epoch 00003: val_loss improved from 1.21750 to 1.06469, saving model to model.weights.best.hdf5
# Epoch 4/100
#  - 5s - loss: 1.0228 - acc: 0.6425 - val_loss: 0.9719 - val_acc: 0.6698
#
# Epoch 00004: val_loss improved from 1.06469 to 0.97186, saving model to model.weights.best.hdf5
# Epoch 5/100
#  - 5s - loss: 0.9788 - acc: 0.6620 - val_loss: 1.0969 - val_acc: 0.6082
#
# Epoch 00005: val_loss did not improve from 0.97186
# Epoch 6/100
#  - 5s - loss: 0.9556 - acc: 0.6719 - val_loss: 0.8739 - val_acc: 0.6976
#
# Epoch 00006: val_loss improved from 0.97186 to 0.87389, saving model to model.weights.best.hdf5
# Epoch 7/100
#  - 5s - loss: 0.9436 - acc: 0.6791 - val_loss: 1.0029 - val_acc: 0.6788
#
# Epoch 00007: val_loss did not improve from 0.87389
# Epoch 8/100
#  - 5s - loss: 0.9362 - acc: 0.6836 - val_loss: 0.9005 - val_acc: 0.6968
#
# Epoch 00008: val_loss did not improve from 0.87389
# Epoch 9/100
#  - 5s - loss: 0.9361 - acc: 0.6831 - val_loss: 1.0510 - val_acc: 0.6616
#
# Epoch 00009: val_loss did not improve from 0.87389
# Epoch 10/100
#  - 5s - loss: 0.9359 - acc: 0.6863 - val_loss: 0.8926 - val_acc: 0.7018
#
# Epoch 00010: val_loss did not improve from 0.87389
# Epoch 11/100
#  - 5s - loss: 0.9459 - acc: 0.6862 - val_loss: 0.8898 - val_acc: 0.7086
#
# Epoch 00011: val_loss did not improve from 0.87389
# Epoch 12/100
#  - 5s - loss: 0.9643 - acc: 0.6812 - val_loss: 1.2574 - val_acc: 0.6276
#
# Epoch 00012: val_loss did not improve from 0.87389
# Epoch 13/100
#  - 5s - loss: 0.9711 - acc: 0.6780 - val_loss: 1.0720 - val_acc: 0.6432
#
# Epoch 00013: val_loss did not improve from 0.87389
# Epoch 14/100
#  - 5s - loss: 0.9822 - acc: 0.6752 - val_loss: 0.9654 - val_acc: 0.6898
#
# Epoch 00014: val_loss did not improve from 0.87389
# Epoch 15/100
#  - 5s - loss: 0.9970 - acc: 0.6704 - val_loss: 1.1165 - val_acc: 0.6480
#
# Epoch 00015: val_loss did not improve from 0.87389
# Epoch 16/100
#  - 5s - loss: 1.0168 - acc: 0.6656 - val_loss: 0.9820 - val_acc: 0.6754
#
# Epoch 00016: val_loss did not improve from 0.87389
# Epoch 17/100
#  - 5s - loss: 1.0316 - acc: 0.6634 - val_loss: 0.8727 - val_acc: 0.7116
#
# Epoch 00017: val_loss improved from 0.87389 to 0.87268, saving model to model.weights.best.hdf5
# Epoch 18/100
#  - 5s - loss: 1.0474 - acc: 0.6574 - val_loss: 0.9529 - val_acc: 0.6726
#
# Epoch 00018: val_loss did not improve from 0.87268
# Epoch 19/100
#  - 5s - loss: 1.0572 - acc: 0.6529 - val_loss: 0.9485 - val_acc: 0.6922
#
# Epoch 00019: val_loss did not improve from 0.87268
# Epoch 20/100
#  - 5s - loss: 1.0780 - acc: 0.6470 - val_loss: 1.3207 - val_acc: 0.6538
#
# Epoch 00020: val_loss did not improve from 0.87268
# Epoch 21/100
#  - 5s - loss: 1.0890 - acc: 0.6436 - val_loss: 1.0438 - val_acc: 0.6552
#
# Epoch 00021: val_loss did not improve from 0.87268
# Epoch 22/100
#  - 5s - loss: 1.1026 - acc: 0.6376 - val_loss: 1.2141 - val_acc: 0.6900
#
# Epoch 00022: val_loss did not improve from 0.87268
# Epoch 23/100
#  - 5s - loss: 1.1151 - acc: 0.6372 - val_loss: 1.2632 - val_acc: 0.6048
#
# Epoch 00023: val_loss did not improve from 0.87268
# Epoch 24/100
#  - 5s - loss: 1.1211 - acc: 0.6314 - val_loss: 1.7586 - val_acc: 0.5418
#
# Epoch 00024: val_loss did not improve from 0.87268
# Epoch 25/100
#  - 5s - loss: 1.1474 - acc: 0.6239 - val_loss: 1.4203 - val_acc: 0.6152
#
# Epoch 00025: val_loss did not improve from 0.87268
# Epoch 26/100
#  - 5s - loss: 1.1625 - acc: 0.6210 - val_loss: 0.9636 - val_acc: 0.6814
#
# Epoch 00026: val_loss did not improve from 0.87268
# Epoch 27/100
#  - 5s - loss: 1.1910 - acc: 0.6118 - val_loss: 1.1489 - val_acc: 0.5976
#
# Epoch 00027: val_loss did not improve from 0.87268
# Epoch 28/100
#  - 5s - loss: 1.2119 - acc: 0.6055 - val_loss: 1.1913 - val_acc: 0.6012
#
# Epoch 00028: val_loss did not improve from 0.87268
# Epoch 29/100
#  - 5s - loss: 1.2125 - acc: 0.6018 - val_loss: 1.0130 - val_acc: 0.6816
#
# Epoch 00029: val_loss did not improve from 0.87268
# Epoch 30/100
#  - 5s - loss: 1.2231 - acc: 0.5992 - val_loss: 1.3985 - val_acc: 0.5894
#
# Epoch 00030: val_loss did not improve from 0.87268
# Epoch 31/100
#  - 5s - loss: 1.2449 - acc: 0.5984 - val_loss: 1.2534 - val_acc: 0.6032
#
# Epoch 00031: val_loss did not improve from 0.87268
# Epoch 32/100
#  - 6s - loss: 1.2579 - acc: 0.5872 - val_loss: 1.5301 - val_acc: 0.5256
#
# Epoch 00032: val_loss did not improve from 0.87268
# Epoch 33/100
#  - 5s - loss: 1.2473 - acc: 0.5926 - val_loss: 1.1450 - val_acc: 0.6238
#
# Epoch 00033: val_loss did not improve from 0.87268
# Epoch 34/100
#  - 5s - loss: 1.2619 - acc: 0.5892 - val_loss: 1.3721 - val_acc: 0.5486
#
# Epoch 00034: val_loss did not improve from 0.87268
# Epoch 35/100
#  - 5s - loss: 1.2858 - acc: 0.5779 - val_loss: 1.4937 - val_acc: 0.5318
#
# Epoch 00035: val_loss did not improve from 0.87268
# Epoch 36/100
#  - 5s - loss: 1.3035 - acc: 0.5720 - val_loss: 1.1457 - val_acc: 0.6158
#
# Epoch 00036: val_loss did not improve from 0.87268
# Epoch 37/100
#  - 5s - loss: 1.3043 - acc: 0.5730 - val_loss: 1.6774 - val_acc: 0.4822
#
# Epoch 00037: val_loss did not improve from 0.87268
# Epoch 38/100
#  - 5s - loss: 1.3148 - acc: 0.5704 - val_loss: 1.2913 - val_acc: 0.5780
#
# Epoch 00038: val_loss did not improve from 0.87268
# Epoch 39/100
#  - 5s - loss: 1.3151 - acc: 0.5674 - val_loss: 1.2082 - val_acc: 0.5922
#
# Epoch 00039: val_loss did not improve from 0.87268
# Epoch 40/100
#  - 5s - loss: 1.3391 - acc: 0.5600 - val_loss: 1.8595 - val_acc: 0.5226
#
# Epoch 00040: val_loss did not improve from 0.87268
# Epoch 41/100
#  - 5s - loss: 1.3513 - acc: 0.5586 - val_loss: 1.2008 - val_acc: 0.6022
#
# Epoch 00041: val_loss did not improve from 0.87268
# Epoch 42/100
#  - 5s - loss: 1.3580 - acc: 0.5507 - val_loss: 1.4199 - val_acc: 0.5048
#
# Epoch 00042: val_loss did not improve from 0.87268
# Epoch 43/100
#  - 5s - loss: 1.3791 - acc: 0.5474 - val_loss: 1.1597 - val_acc: 0.5930
#
# Epoch 00043: val_loss did not improve from 0.87268
# Epoch 44/100
#  - 5s - loss: 1.3870 - acc: 0.5415 - val_loss: 1.1498 - val_acc: 0.6164
#
# Epoch 00044: val_loss did not improve from 0.87268
# Epoch 45/100
#  - 5s - loss: 1.4029 - acc: 0.5356 - val_loss: 1.2942 - val_acc: 0.5718
#
# Epoch 00045: val_loss did not improve from 0.87268
# Epoch 46/100
#  - 5s - loss: 1.4196 - acc: 0.5317 - val_loss: 1.6991 - val_acc: 0.4714
#
# Epoch 00046: val_loss did not improve from 0.87268
# Epoch 47/100
#  - 5s - loss: 1.4445 - acc: 0.5215 - val_loss: 1.5118 - val_acc: 0.5870
#
# Epoch 00047: val_loss did not improve from 0.87268
# Epoch 48/100
#  - 5s - loss: 1.4595 - acc: 0.5156 - val_loss: 1.2958 - val_acc: 0.5548
#
# Epoch 00048: val_loss did not improve from 0.87268
# Epoch 49/100
#  - 5s - loss: 1.4717 - acc: 0.5090 - val_loss: 1.5383 - val_acc: 0.4566
#
# Epoch 00049: val_loss did not improve from 0.87268
# Epoch 50/100
#  - 5s - loss: 1.4928 - acc: 0.4994 - val_loss: 2.3876 - val_acc: 0.4490
#
# Epoch 00050: val_loss did not improve from 0.87268
# Epoch 51/100
#  - 5s - loss: 1.5278 - acc: 0.4873 - val_loss: 1.3302 - val_acc: 0.5298
#
# Epoch 00051: val_loss did not improve from 0.87268
# Epoch 52/100
#  - 5s - loss: 1.5301 - acc: 0.4884 - val_loss: 1.5382 - val_acc: 0.4822
#
# Epoch 00052: val_loss did not improve from 0.87268
# Epoch 53/100
#  - 5s - loss: 1.5298 - acc: 0.4863 - val_loss: 3.4781 - val_acc: 0.3972
#
# Epoch 00053: val_loss did not improve from 0.87268
# Epoch 54/100
#  - 5s - loss: 1.5318 - acc: 0.4875 - val_loss: 1.5074 - val_acc: 0.5460
#
# Epoch 00054: val_loss did not improve from 0.87268
# Epoch 55/100
#  - 5s - loss: 1.5645 - acc: 0.4727 - val_loss: 1.3620 - val_acc: 0.5144
#
# Epoch 00055: val_loss did not improve from 0.87268
# Epoch 56/100
#  - 5s - loss: 1.5913 - acc: 0.4686 - val_loss: 1.4239 - val_acc: 0.4808
#
# Epoch 00056: val_loss did not improve from 0.87268
# Epoch 57/100
#  - 5s - loss: 1.5923 - acc: 0.4645 - val_loss: 1.5570 - val_acc: 0.4634
#
# Epoch 00057: val_loss did not improve from 0.87268
# Epoch 58/100
#  - 5s - loss: 1.5989 - acc: 0.4554 - val_loss: 1.4121 - val_acc: 0.4920
#
# Epoch 00058: val_loss did not improve from 0.87268
# Epoch 59/100
#  - 5s - loss: 1.6195 - acc: 0.4502 - val_loss: 1.4669 - val_acc: 0.4664
#
# Epoch 00059: val_loss did not improve from 0.87268
# Epoch 60/100
#  - 5s - loss: 1.6105 - acc: 0.4506 - val_loss: 1.3742 - val_acc: 0.5026
#
# Epoch 00060: val_loss did not improve from 0.87268
# Epoch 61/100
#  - 5s - loss: 1.6304 - acc: 0.4434 - val_loss: 1.5176 - val_acc: 0.4470
#
# Epoch 00061: val_loss did not improve from 0.87268
# Epoch 62/100
#  - 5s - loss: 1.6251 - acc: 0.4412 - val_loss: 1.3403 - val_acc: 0.5236
#
# Epoch 00062: val_loss did not improve from 0.87268
# Epoch 63/100
#  - 5s - loss: 1.6593 - acc: 0.4372 - val_loss: 1.4665 - val_acc: 0.4806
#
# Epoch 00063: val_loss did not improve from 0.87268
# Epoch 64/100
#  - 5s - loss: 1.6422 - acc: 0.4382 - val_loss: 1.4395 - val_acc: 0.4930
#
# Epoch 00064: val_loss did not improve from 0.87268
# Epoch 65/100
#  - 5s - loss: 1.6524 - acc: 0.4351 - val_loss: 1.5138 - val_acc: 0.4448
#
# Epoch 00065: val_loss did not improve from 0.87268
# Epoch 66/100
#  - 5s - loss: 1.6700 - acc: 0.4300 - val_loss: 1.4370 - val_acc: 0.5348
#
# Epoch 00066: val_loss did not improve from 0.87268
# Epoch 67/100
#  - 5s - loss: 1.6558 - acc: 0.4357 - val_loss: 1.4133 - val_acc: 0.5082
#
# Epoch 00067: val_loss did not improve from 0.87268
# Epoch 68/100
#  - 5s - loss: 1.6501 - acc: 0.4367 - val_loss: 1.5022 - val_acc: 0.4542
#
# Epoch 00068: val_loss did not improve from 0.87268
# Epoch 69/100
#  - 5s - loss: 1.6669 - acc: 0.4342 - val_loss: 1.7626 - val_acc: 0.4370
#
# Epoch 00069: val_loss did not improve from 0.87268
# Epoch 70/100
#  - 5s - loss: 1.6466 - acc: 0.4335 - val_loss: 1.5225 - val_acc: 0.4670
#
# Epoch 00070: val_loss did not improve from 0.87268
# Epoch 71/100
#  - 5s - loss: 1.6727 - acc: 0.4242 - val_loss: 1.4314 - val_acc: 0.4778
#
# Epoch 00071: val_loss did not improve from 0.87268
# Epoch 72/100
#  - 5s - loss: 1.6764 - acc: 0.4235 - val_loss: 2.1308 - val_acc: 0.4536
#
# Epoch 00072: val_loss did not improve from 0.87268
# Epoch 73/100
#  - 5s - loss: 1.6514 - acc: 0.4362 - val_loss: 1.5083 - val_acc: 0.4334
#
# Epoch 00073: val_loss did not improve from 0.87268
# Epoch 74/100
#  - 5s - loss: 1.6578 - acc: 0.4318 - val_loss: 2.0234 - val_acc: 0.3508
#
# Epoch 00074: val_loss did not improve from 0.87268
# Epoch 75/100
#  - 5s - loss: 1.7036 - acc: 0.4194 - val_loss: 1.6568 - val_acc: 0.3850
#
# Epoch 00075: val_loss did not improve from 0.87268
# Epoch 76/100
#  - 5s - loss: 1.7014 - acc: 0.4121 - val_loss: 1.4260 - val_acc: 0.4766
#
# Epoch 00076: val_loss did not improve from 0.87268
# Epoch 77/100
#  - 5s - loss: 1.6985 - acc: 0.4158 - val_loss: 1.4401 - val_acc: 0.4654
#
# Epoch 00077: val_loss did not improve from 0.87268
# Epoch 78/100
#  - 5s - loss: 1.6940 - acc: 0.4141 - val_loss: 2.8617 - val_acc: 0.3654
#
# Epoch 00078: val_loss did not improve from 0.87268
# Epoch 79/100
#  - 5s - loss: 1.7052 - acc: 0.4080 - val_loss: 1.5760 - val_acc: 0.4390
#
# Epoch 00079: val_loss did not improve from 0.87268
# Epoch 80/100
#  - 5s - loss: 1.7006 - acc: 0.4130 - val_loss: 1.9092 - val_acc: 0.3348
#
# Epoch 00080: val_loss did not improve from 0.87268
# Epoch 81/100
#  - 5s - loss: 1.7067 - acc: 0.4047 - val_loss: 1.5537 - val_acc: 0.4428
#
# Epoch 00081: val_loss did not improve from 0.87268
# Epoch 82/100
#  - 5s - loss: 1.7066 - acc: 0.4042 - val_loss: 1.4449 - val_acc: 0.5262
#
# Epoch 00082: val_loss did not improve from 0.87268
# Epoch 83/100
#  - 5s - loss: 1.7222 - acc: 0.4027 - val_loss: 2.0560 - val_acc: 0.3584
#
# Epoch 00083: val_loss did not improve from 0.87268
# Epoch 84/100
#  - 5s - loss: 1.7223 - acc: 0.3982 - val_loss: 1.4223 - val_acc: 0.4912
#
# Epoch 00084: val_loss did not improve from 0.87268
# Epoch 85/100
#  - 5s - loss: 1.7297 - acc: 0.3992 - val_loss: 1.5273 - val_acc: 0.5024
#
# Epoch 00085: val_loss did not improve from 0.87268
# Epoch 86/100
#  - 5s - loss: 1.7440 - acc: 0.3891 - val_loss: 1.6649 - val_acc: 0.3838
#
# Epoch 00086: val_loss did not improve from 0.87268
# Epoch 87/100
#  - 5s - loss: 1.7454 - acc: 0.3860 - val_loss: 1.4419 - val_acc: 0.4860
#
# Epoch 00087: val_loss did not improve from 0.87268
# Epoch 88/100
#  - 5s - loss: 1.7589 - acc: 0.3804 - val_loss: 1.6150 - val_acc: 0.4192
#
# Epoch 00088: val_loss did not improve from 0.87268
# Epoch 89/100
#  - 5s - loss: 1.7809 - acc: 0.3789 - val_loss: 1.6654 - val_acc: 0.4246
#
# Epoch 00089: val_loss did not improve from 0.87268
# Epoch 90/100
#  - 5s - loss: 1.7724 - acc: 0.3782 - val_loss: 1.6845 - val_acc: 0.3722
#
# Epoch 00090: val_loss did not improve from 0.87268
# Epoch 91/100
#  - 5s - loss: 1.7838 - acc: 0.3766 - val_loss: 1.8801 - val_acc: 0.3664
#
# Epoch 00091: val_loss did not improve from 0.87268
# Epoch 92/100
#  - 5s - loss: 1.8136 - acc: 0.3656 - val_loss: 1.9383 - val_acc: 0.2958
#
# Epoch 00092: val_loss did not improve from 0.87268
# Epoch 93/100
#  - 5s - loss: 1.8180 - acc: 0.3653 - val_loss: 1.5915 - val_acc: 0.4256
#
# Epoch 00093: val_loss did not improve from 0.87268
# Epoch 94/100
#  - 5s - loss: 1.7993 - acc: 0.3674 - val_loss: 2.0363 - val_acc: 0.3568
#
# Epoch 00094: val_loss did not improve from 0.87268
# Epoch 95/100
#  - 5s - loss: 1.7982 - acc: 0.3662 - val_loss: 1.7133 - val_acc: 0.4700
#
# Epoch 00095: val_loss did not improve from 0.87268
# Epoch 96/100
#  - 5s - loss: 1.8198 - acc: 0.3601 - val_loss: 1.5345 - val_acc: 0.4212
#
# Epoch 00096: val_loss did not improve from 0.87268
# Epoch 97/100
#  - 5s - loss: 1.8099 - acc: 0.3624 - val_loss: 1.6036 - val_acc: 0.4064
#
# Epoch 00097: val_loss did not improve from 0.87268
# Epoch 98/100
#  - 5s - loss: 1.8139 - acc: 0.3575 - val_loss: 1.5336 - val_acc: 0.4496
#
# Epoch 00098: val_loss did not improve from 0.87268
# Epoch 99/100
#  - 5s - loss: 1.8354 - acc: 0.3553 - val_loss: 1.5384 - val_acc: 0.4062
#
# Epoch 00099: val_loss did not improve from 0.87268
# Epoch 100/100
#  - 5s - loss: 1.8519 - acc: 0.3537 - val_loss: 1.5570 - val_acc: 0.4542
#
# Epoch 00100: val_loss did not improve from 0.87268

# %% [markdown]
# ### 8. Load the Model with the Best Validation Accuracy

# %%
# load the weights that yielded the best validation accuracy
model.load_weights('model.weights.best.hdf5')

# %% [markdown]
# ### 9. Calculate Classification Accuracy on Test Set

# %%
# evaluate and print test accuracy
score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
#  Test accuracy: 0.7016

# %% [markdown]
# ### 10. Visualize Some Predictions
#
# This may give you some insight into why the network is misclassifying certain objects.

# %%
# get predictions on the test set
y_hat = model.predict(x_test)

# define text labels (source: https://www.cs.toronto.edu/~kriz/cifar.html)
cifar10_labels = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# plot a random sample of test images, their predicted labels, and ground truth
fig = plt.figure(figsize=(20, 8))
for i, idx in enumerate(np.random.choice(x_test.shape[0], size=32, replace=False)):
    ax = fig.add_subplot(4, 8, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_test[idx]))
    pred_idx = np.argmax(y_hat[idx])
    true_idx = np.argmax(y_test[idx])
    ax.set_title("{} ({})".format(cifar10_labels[pred_idx], cifar10_labels[true_idx]),
                 color=("green" if pred_idx == true_idx else "red"))
